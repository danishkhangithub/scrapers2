# %%
import pandas as pd
import numpy as np
import os

# %%
data = pd.read_csv(r'cars.csv')
data
# Out:
#                                Name    Price         Vin Number  \
# 0              2018 GMC Sierra 1500  $36,990  3GTU2NEC8JG446325
# 1            2017 Ford C-Max Energi  $13,990  1FADP5EUXHL104632
# 2     2019 Chevrolet Silverado 1500  $37,999  1GCRYEED4KZ200547
# 3              2016 GMC Sierra 1500  $40,499  3GTU2NEC2GG149866
# 4           2018 Chevrolet Colorado  $34,499  1GCPTDE10J1116888
# ...                             ...      ...                ...
# 5172            2018 Subaru Outback  $25,590  4S4BSAACXJ3289210
# 5173        2013 Chevrolet Corvette  $37,590  1G1YE3DWXD5100242
# 5174   2017 Mercedes-Benz GLC-Class  $48,499  WDC0G6EB4HF220057
# 5175               2015 Ford Taurus  $19,990  1FAHP2E80FG207387
# 5176           2017 FIAT 124 Spider  $26,590  JC1NFAEK5H0105145
#
#                                         Vehicle Summary  \
# 0     75,801 miles, automatic transmission, four whe...
# 1     40,545 miles, automatic transmission, front wh...
# ...

# %%
data2 = data.copy()

# %%
null_values = data.isnull().sum()
null_values
# Out:
# Name                     24
# Price                    24
# Vin Number               24
# Vehicle Summary          24
# Top features & Specs    215
# dtype: int64

# %%
exel = data.to_excel('cars.xlsx')

# %%
df = pd.read_excel('cars.xlsx')
df.drop(columns = "Unnamed: 0", inplace=True, axis=1)

# %%
df.to_excel('cars.xlsx')

# %%
df
# Out:
#                                Name    Price         Vin Number  \
# 0              2018 GMC Sierra 1500  $36,990  3GTU2NEC8JG446325
# 1            2017 Ford C-Max Energi  $13,990  1FADP5EUXHL104632
# 2     2019 Chevrolet Silverado 1500  $37,999  1GCRYEED4KZ200547
# 3              2016 GMC Sierra 1500  $40,499  3GTU2NEC2GG149866
# 4           2018 Chevrolet Colorado  $34,499  1GCPTDE10J1116888
# ...                             ...      ...                ...
# 5172            2018 Subaru Outback  $25,590  4S4BSAACXJ3289210
# 5173        2013 Chevrolet Corvette  $37,590  1G1YE3DWXD5100242
# 5174   2017 Mercedes-Benz GLC-Class  $48,499  WDC0G6EB4HF220057
# 5175               2015 Ford Taurus  $19,990  1FAHP2E80FG207387
# 5176           2017 FIAT 124 Spider  $26,590  JC1NFAEK5H0105145
#
#                                         Vehicle Summary  \
# 0     75,801 miles, automatic transmission, four whe...
# 1     40,545 miles, automatic transmission, front wh...
# ...
